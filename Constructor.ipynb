# %% [markdown]
# This archive is for save the images. Run this script if and only if you want to reconstruct the images.

# %%
import os

os.makedirs("LionI", exist_ok = True)
os.makedirs("CurveI", exist_ok = True)
os.makedirs("MandelbrotI", exist_ok = True)
os.makedirs("SimpleTriImage", exist_ok = True)
os.makedirs("ShareTriImage", exist_ok = True)
os.makedirs("DistTriImage", exist_ok = True)

# %%
Resolutions_Lion = [[40, 40], [160, 160]]
Resolutions_Curve = [[20, 20], [40, 40], [80, 80], [320, 320], [1280, 1280]]
Resolutions_Triangle = [[10,10], [20,20], [40,40], [80,80], [320,320],[1280,1280]]

# %% [markdown]
# # Simple Triangle

# %%
# Simple Triangle in many resolutions

for a,b in Resolutions_Triangle:

    output_path = f"SimpleTriImage/SimpleTri_{a}_{b}.png"

    # !python3 raster.py -s "triangle_scene" -o "{output_path}" -r {a} {b} -w 0 4 0 4
# Out:
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████████████| 100/100 [00:00<00:00, 199159.73it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████████████| 400/400 [00:00<00:00, 251607.92it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 1600/1600 [00:00<00:00, 264280.96it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 6400/6400 [00:00<00:00, 202579.04it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████| 102400/102400 [00:00<00:00, 276399.56it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████| 1638400/1638400 [00:05<00:00, 283656.66it/s]

# %% [markdown]
# # Share Triangles

# %%
# Share Triangles in many resolutions

os.makedirs("ShareTriImage", exist_ok = True)

for a,b in Resolutions_Triangle:

    output_path = f"ShareTriImage/ShareTri_{a}_{b}.png"

    # !python3 raster.py -s "triangle_scene_share" -o "{output_path}" -r {a} {b} -w 0 6 0 6
# Out:
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████████████| 100/100 [00:00<00:00, 187078.68it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████████████| 400/400 [00:00<00:00, 227611.12it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 1600/1600 [00:00<00:00, 239880.13it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 6400/6400 [00:00<00:00, 250455.27it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████| 102400/102400 [00:00<00:00, 249468.38it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████| 1638400/1638400 [00:06<00:00, 249470.69it/s]

# %% [markdown]
# # Dist Triangles

# %%
# Dist Triangles  0.2 in many resolutions

os.makedirs("DistTI02", exist_ok = True)

for a,b in Resolutions_Triangle:

    output_path = f"DistTI02/Dist02Tri_{a}_{b}.png"

    # !python3 raster.py -s "triangle_scene_dist02" -o "{output_path}" -r {a} {b} -w 0 6 0 6
# Out:
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████████████| 100/100 [00:00<00:00, 165913.92it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████████████| 400/400 [00:00<00:00, 176157.24it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 1600/1600 [00:00<00:00, 242314.01it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 6400/6400 [00:00<00:00, 249563.47it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████| 102400/102400 [00:00<00:00, 246847.98it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████| 1638400/1638400 [00:06<00:00, 242362.80it/s]

# %%
# Dist Triangles  0.005 in many resolutions

os.makedirs("DistTI005", exist_ok = True)

for a,b in Resolutions_Triangle:

    output_path = f"DistTI005/Dist005Tri_{a}_{b}.png"

    # !python3 raster.py -s "triangle_scene_dist005" -o "{output_path}" -r {a} {b} -w 0 6 0 6
# Out:
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████████████| 100/100 [00:00<00:00, 185506.59it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████████████| 400/400 [00:00<00:00, 222834.59it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 1600/1600 [00:00<00:00, 143862.25it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 6400/6400 [00:00<00:00, 246368.25it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████| 102400/102400 [00:00<00:00, 253772.48it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████| 1638400/1638400 [00:06<00:00, 252097.02it/s]

# %% [markdown]
# # Lion Process

# %%
# Normal images for Lion

os.makedirs("LionI/LionImage", exist_ok = True)

for a,b in Resolutions_Lion:

    output_path = f"LionI/LionImage/lion_{a}_{b}.png"

    # !python3 raster.py -s "lion_scene" -o "{output_path}" -r {a} {b} -w -10 248 -8 389
# Out:
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████████| 1600/1600 [00:09<00:00, 176.31it/s]
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|████████████████████████████████████| 25600/25600 [02:22<00:00, 179.19it/s]
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████| 102400/102400 [09:30<00:00, 179.54it/s]
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████| 409600/409600 [37:58<00:00, 179.77it/s]

# %%
# Gaussian images for Lion

os.makedirs("LionI/LionImageGaus", exist_ok = True)

for a,b in Resolutions_Lion:

    output_path = f"LionI/LionImageGaus/lion_{a}_{b}.png"

    # !python3 raster.py -s "lion_scene" -o "{output_path}" -r {a} {b} -w -10 248 -8 389 -k "gaussian" -n 25

# %%
# Box images for Lion

os.makedirs("LionI/LionImageBox", exist_ok = True)

for a,b in Resolutions_Lion:

    output_path = f"LionI/LionImageBox/lion_{a}_{b}.png"

    # !python3 raster.py -s "lion_scene" -o "{output_path}" -r {a} {b} -w -10 248 -8 389 -k "box" -n 25

# %%
# Hat images for Lion

os.makedirs("LionI/LionImageHat", exist_ok = True)

for a,b in Resolutions_Lion:

    output_path = f"LionI/LionImageHat/lion_{a}_{b}.png"

    # !python3 raster.py -s "lion_scene" -o "{output_path}" -r {a} {b} -w -10 248 -8 389 -k "hat" -n 25

# %% [markdown]
# # Implicit Curve

# %% [markdown]
# For implicit Curve, if you want to rotate, make the change in "special_curve.py"

# %%
# Normal images for Implicit Curve

os.makedirs("CurveI/CurveImage", exist_ok=True)

for a,b in Resolutions_Curve:

    output_path = f"CurveI/CurveImage/curve_{a}_{b}.png"

    # !python3 raster.py -s "special_curve" -o "{output_path}" -r {a} {b} -w -3 3 -3 3
# Out:
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████████████| 400/400 [00:00<00:00, 246978.01it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 1600/1600 [00:00<00:00, 260839.80it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 6400/6400 [00:00<00:00, 266964.48it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████| 102400/102400 [00:00<00:00, 265035.38it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████| 1638400/1638400 [00:06<00:00, 270081.41it/s]

# %%
# Hat images for Implicit Curve

os.makedirs("CurveI/CurveImageHat", exist_ok = True)

for a,b in Resolutions_Curve:

    output_path = f"CurveI/CurveImageHat/curve_{a}_{b}.png"

    # !python3 raster.py -s "special_curve" -o "{output_path}" -r {a} {b} -w -3 3 -3 3 -k "hat" -n 25
# Out:
# Renderizando com Kernel: hat | Amostras: 25
# 100%|███████████████████████████████████████| 400/400 [00:00<00:00, 8982.92it/s]
# Renderizando com Kernel: hat | Amostras: 25
# 100%|█████████████████████████████████████| 1600/1600 [00:00<00:00, 8960.43it/s]
# Renderizando com Kernel: hat | Amostras: 25
# 100%|█████████████████████████████████████| 6400/6400 [00:00<00:00, 9094.83it/s]
# Renderizando com Kernel: hat | Amostras: 25
# 100%|█████████████████████████████████| 102400/102400 [00:11<00:00, 8547.62it/s]
# Renderizando com Kernel: hat | Amostras: 25
# 100%|███████████████████████████████| 1638400/1638400 [03:40<00:00, 7421.41it/s]

# %%
# Box images for Implicit Curve

os.makedirs("CurveI/CurveImageBox", exist_ok = True)

for a,b in Resolutions_Curve:

    output_path = f"CurveI/CurveImageBox/curve_{a}_{b}.png"

    # !python3 raster.py -s "special_curve" -o "{output_path}" -r {a} {b} -w -3 3 -3 3 -k "box" -n 25
# Out:
# Renderizando com Kernel: box | Amostras: 25
# 100%|███████████████████████████████████████| 400/400 [00:00<00:00, 9678.57it/s]
# Renderizando com Kernel: box | Amostras: 25
# 100%|█████████████████████████████████████| 1600/1600 [00:00<00:00, 9619.16it/s]
# Renderizando com Kernel: box | Amostras: 25
# 100%|█████████████████████████████████████| 6400/6400 [00:00<00:00, 9573.70it/s]
# Renderizando com Kernel: box | Amostras: 25
# 100%|█████████████████████████████████| 102400/102400 [00:11<00:00, 9239.69it/s]
# Renderizando com Kernel: box | Amostras: 25
# 100%|███████████████████████████████| 1638400/1638400 [02:51<00:00, 9537.30it/s]

# %%
# Gaussian images for Implicit Curve

os.makedirs("CurveI/CurveImageGaus", exist_ok = True)

for a,b in Resolutions_Curve:

    output_path = f"CurveI/CurveImageGaus/curve_{a}_{b}.png"

    # !python3 raster.py -s "special_curve" -o "{output_path}" -r {a} {b} -w -3 3 -3 3 -k "gaussian" -n 25

os.makedirs("CurveI/CurveImage", exist_ok = True)
# Out:
# Renderizando com Kernel: gaussian | Amostras: 25
# 100%|███████████████████████████████████████| 400/400 [00:00<00:00, 7117.04it/s]
# Renderizando com Kernel: gaussian | Amostras: 25
# 100%|█████████████████████████████████████| 1600/1600 [00:00<00:00, 8365.01it/s]
# Renderizando com Kernel: gaussian | Amostras: 25
# 100%|█████████████████████████████████████| 6400/6400 [00:00<00:00, 8361.05it/s]
# Renderizando com Kernel: gaussian | Amostras: 25
# 100%|█████████████████████████████████| 102400/102400 [00:11<00:00, 8556.86it/s]
# Renderizando com Kernel: gaussian | Amostras: 25
# 100%|███████████████████████████████| 1638400/1638400 [03:13<00:00, 8462.40it/s]

# %% [markdown]
# # Mandelbrot

# %%
for a,b in Resolutions_Curve:

    output_path = f"MandelbrotI/Mandelbrot_{a}_{b}.png"

    # !python3 raster.py -s "mandelbrot" -o "{output_path}" -r {a} {b} -w -2 2 -2 2
# Out:
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████████████| 400/400 [00:00<00:00, 116987.77it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 1600/1600 [00:00<00:00, 120366.01it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████| 6400/6400 [00:00<00:00, 123278.60it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████| 102400/102400 [00:00<00:00, 124251.48it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|█████████████████████████████| 1638400/1638400 [00:13<00:00, 124830.30it/s]
