# %%
import os

# %%
resolutions_list = [[1, 1], [10, 10]]
for i in range(1, 10):
    resolutions_list.append([10 * (2**i), 10 * 2**i])

# %%
os.makedirs("LionImageGaussian", exist_ok = True)
for a,b in resolutions_list[]:
    output_path = f"LionImageGaussian/lion_gaus_{a}_{b}.png"

    # !python3 raster.py -s "lion_scene" -o "{output_path}" -r {a} {b} -w -10 248 -8 389 -k "gaussian" -n 4
# Out:
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Renderizando com Kernel: gaussian | Amostras: 4
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 18.25it/s]
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Renderizando com Kernel: gaussian | Amostras: 4
# 100%|█████████████████████████████████████████| 100/100 [00:05<00:00, 18.97it/s]
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Renderizando com Kernel: gaussian | Amostras: 4
# 100%|█████████████████████████████████████████| 400/400 [00:24<00:00, 16.54it/s]
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Renderizando com Kernel: gaussian | Amostras: 4
# 100%|███████████████████████████████████████| 1600/1600 [01:07<00:00, 23.81it/s]
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# Renderizando com Kernel: gaussian | Amostras: 4
# 100%|███████████████████████████████████████| 6400/6400 [03:59<00:00, 26.69it/s]
# Lion bounding box: x(0.0, 238.0), y(2.0, 379.0)
# ...

# %%
import os
os.makedirs("special_curve_img_ROT", exist_ok=True)

for a, b in resolutions_list:
    output_path = f"special_curve_img_ROT/sp_curve_img_{a}_{b}.png"
    
    # !python3 raster.py -s "special_curve" -o "{output_path}" -r {a} {b} -w 0 -4 -5 2
# Out:
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 7025.63it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████████| 100/100 [00:00<00:00, 73506.91it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████████| 400/400 [00:00<00:00, 82626.03it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|████████████████████████████████████| 1600/1600 [00:00<00:00, 86874.57it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|████████████████████████████████████| 6400/6400 [00:00<00:00, 86327.25it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████| 25600/25600 [00:00<00:00, 85752.13it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|████████████████████████████████| 102400/102400 [00:01<00:00, 87334.51it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# ...

# %%
import os
os.makedirs("zspctrilanc", exist_ok=True)

for a, b in resolutions_list:
    output_path = f"zspctrilanc/spec_{a}_{b}.png"
    
    # !python3 raster.py -s "zspctri" -o "{output_path}" -r {a} {b} -w -1 8 -1 8 -k "lanczos" -n 10
# Out:
# Renderizando com Kernel: lanczos | Amostras: 10
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 54.91it/s]
# Renderizando com Kernel: lanczos | Amostras: 10
# 100%|███████████████████████████████████████| 100/100 [00:00<00:00, 1078.88it/s]
# Renderizando com Kernel: lanczos | Amostras: 10
# 100%|███████████████████████████████████████| 400/400 [00:00<00:00, 1456.91it/s]
# Renderizando com Kernel: lanczos | Amostras: 10
# 100%|█████████████████████████████████████| 1600/1600 [00:01<00:00, 1400.45it/s]
# Renderizando com Kernel: lanczos | Amostras: 10
# 100%|█████████████████████████████████████| 6400/6400 [00:04<00:00, 1447.10it/s]
# Renderizando com Kernel: lanczos | Amostras: 10
# 100%|███████████████████████████████████| 25600/25600 [00:17<00:00, 1455.20it/s]
# Renderizando com Kernel: lanczos | Amostras: 10
# 100%|█████████████████████████████████| 102400/102400 [01:11<00:00, 1434.66it/s]
# Renderizando com Kernel: lanczos | Amostras: 10
# ...

# %%
resolutions_list = [[1, 1], [10, 10]]
for i in range(1, 12):
    resolutions_list.append([10 * (2**i), 10 * 2**i])

# %%
import os
os.makedirs("mandelbrot", exist_ok=True)

for a, b in resolutions_list[:9]:
    output_path = f"mandelbrot/mdbr_{a}_{b}.png"
    
    # !python3 raster.py -s "mandelbrot" -o "{output_path}" -r {a} {b} -w -2 2 -2 2
# Out:
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 5940.94it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████████| 100/100 [00:00<00:00, 43093.64it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████████| 400/400 [00:00<00:00, 50683.39it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|████████████████████████████████████| 1600/1600 [00:00<00:00, 42848.48it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|████████████████████████████████████| 6400/6400 [00:00<00:00, 45756.33it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████| 25600/25600 [00:00<00:00, 51904.96it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|████████████████████████████████| 102400/102400 [00:02<00:00, 49269.63it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# ...

# %%
import os
os.makedirs("ZZZZMANDEL", exist_ok=True)

for a, b in resolutions_list:
    output_path = f"ZZZZMANDEL/spec_{a}_{b}.png"
    
    # !python3 raster.py -s "mandelbrot" -o "{output_path}" -r {a} {b} -w -2 2 -2 2
# Out:
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 5957.82it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████████| 100/100 [00:00<00:00, 47016.07it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████████| 400/400 [00:00<00:00, 50780.04it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|████████████████████████████████████| 1600/1600 [00:00<00:00, 50663.49it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|████████████████████████████████████| 6400/6400 [00:00<00:00, 51140.30it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|██████████████████████████████████| 25600/25600 [00:00<00:00, 52899.44it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# 100%|████████████████████████████████| 102400/102400 [00:01<00:00, 54055.02it/s]
# Renderizando com Kernel: Nenhum | Amostras: 1
# ...
